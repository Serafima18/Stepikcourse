# %%
import pandas as pd
from StepikAPI import *
from config import token

st = StepikAPI(token, course_id=188376)
st.get_data()
df = pd.DataFrame(st.get_sections())
df
# Out:
#           0       1                                                  2
# 0   section  365061  {'title': 'Введение', 'position': 1, 'course':...
# 1   section  365062  {'title': 'Арифметика и переменные', 'position...
# 2   section  365713  {'title': 'Функции', 'position': 3, 'course': ...
# 3   section  371384  {'title': 'Условные операторы', 'position': 4,...
# 4   section  389712  {'title': 'Циклы', 'position': 5, 'course': 18...
# 5   section  371385  {'title': 'Циклы (в работе)', 'position': 6, '...
# 6   section  371386  {'title': 'Игра (дополнительный материал)', 'p...
# 7   section  371387  {'title': 'ООП', 'position': 8, 'course': 188376}
# 8   section  371388  {'title': 'Игра с ООП (дополнительный материал...
# 9   section  371389  {'title': 'Заключение', 'position': 10, 'cours...
# 10  section  388364  {'title': 'Приложение', 'position': 11, 'cours...

# %%
df = pd.DataFrame(st.get_units())
df
# Out:
#        0        1                                                  2
# 0   unit  1151729  {'position': 1, 'section': 365061, 'lesson': 1...
# 1   unit  1151730  {'position': 2, 'section': 365061, 'lesson': 1...
# 2   unit  1151731  {'position': 1, 'section': 365062, 'lesson': 1...
# 3   unit  1151953  {'position': 2, 'section': 365062, 'lesson': 1...
# 4   unit  1151954  {'position': 3, 'section': 365062, 'lesson': 1...
# 5   unit  1151955  {'position': 4, 'section': 365062, 'lesson': 1...
# 6   unit  1151956  {'position': 5, 'section': 365062, 'lesson': 1...
# 7   unit  1151957  {'position': 6, 'section': 365062, 'lesson': 1...
# 8   unit  1156657  {'position': 7, 'section': 365062, 'lesson': 1...
# 9   unit  1153761  {'position': 1, 'section': 365713, 'lesson': 1...
# 10  unit  1166930  {'position': 2, 'section': 365713, 'lesson': 1...
# 11  unit  1167027  {'position': 3, 'section': 365713, 'lesson': 1...
# 12  unit  1171431  {'position': 4, 'section': 365713, 'lesson': 1...
# ...

# %%
df = pd.DataFrame(st.get_lessons())
df
# Out:
#          0        1                                                  2
# 0   lesson   414777  {'title': 'for и range()', 'is_public': True, ...
# 1   lesson   414778  {'title': 'while', 'is_public': True, 'languag...
# 2   lesson   588212  {'title': 'Область видимости', 'is_public': Tr...
# 3   lesson  1112154  {'title': 'операторы сравнения', 'is_public': ...
# 4   lesson  1120987  {'title': 'while для обработки ввода', 'is_pub...
# 5   lesson  1133855  {'title': 'sum, min, max', 'is_public': False,...
# 6   lesson  1140054  {'title': 'Как учиться на курсе', 'is_public':...
# 7   lesson  1140055  {'title': 'Установим программы', 'is_public': ...
# 8   lesson  1140056  {'title': 'python как калькулятор', 'is_public...
# 9   lesson  1140280  {'title': 'переменные', 'is_public': False, 'l...
# 10  lesson  1140281  {'title': 'программа в файле, print()', 'is_pu...
# 11  lesson  1140282  {'title': 'ввод данных, input()', 'is_public':...
# ...

# %%
df = pd.DataFrame(st.get_steps())
df
# Out:
#        0        1                                                  2
# 0   step  1608757  {'lesson': 414777, 'position': 1, 'block_name'...
# 1   step  1608758  {'lesson': 414778, 'position': 1, 'block_name'...
# 2   step  2398194  {'lesson': 588212, 'position': 1, 'block_name'...
# 3   step  1609063  {'lesson': 414778, 'position': 2, 'block_name'...
# 4   step  5445063  {'lesson': 414777, 'position': 2, 'block_name'...
# 5   step  1608834  {'lesson': 414777, 'position': 3, 'block_name'...
# 6   step  1609064  {'lesson': 414778, 'position': 3, 'block_name'...
# 7   step  1609066  {'lesson': 414778, 'position': 4, 'block_name'...
# 8   step  4665160  {'lesson': 414777, 'position': 4, 'block_name'...
# 9   step  1609067  {'lesson': 414778, 'position': 5, 'block_name'...
# 10  step  4665159  {'lesson': 414777, 'position': 5, 'block_name'...
# 11  step  1608843  {'lesson': 414777, 'position': 6, 'block_name'...
# 12  step  4654380  {'lesson': 414778, 'position': 6, 'block_name'...
# ...
