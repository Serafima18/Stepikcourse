# %%
import pandas as pd
from classesAPI import *
from config import token
from pprint import pprint

# %%
grade_book = GradeBook(token, course_id='188376', class_id='62475')
pprint(grade_book.get_grades())
df = pd.DataFrame.from_dict(grade_book.get_student_grades(student_id=944335224), orient='index', columns=['Score'])
df
# Out:
# [{'certificate_issue_date': None,
#   'certificate_issue_distinction_date': None,
#   'certificate_issue_regular_date': None,
#   'certificate_update_date': None,
#   'certificate_url': None,
#   'course': 188376,
#   'date_joined': '2024-09-08T09:00:51Z',
#   'id': 29837854,
#   'is_teacher': False,
#   'last_viewed': '2024-09-29T12:41:19Z',
#   'rank': None,
#   'rank_max': None,
#   'rank_position': None,
#   'results': {'1108157-1': {'first_success': None,
#                             'is_passed': True,
#                             'score': 2.0,
#                             'step_id': 4602136,
#                             'total_submissions': 0},
#               '1108157-2': {'first_success': None,
#                             'is_passed': True,
#                             'score': 2.0,
#                             'step_id': 5170391,
#                             'total_submissions': 0},
#               '1108157-3': {'first_success': None,
# ...

# %% [markdown]
# ### Пример словаря с оценками
# ``` json
# {
#     student_id:
#         {step_id: grade}
# }
# ```

# %%
grade_book.get_grades_pair()
# Out:
# {944335224: {4818237: 0,
#   4818238: 0,
#   4818239: 0,
#   4818266: 0,
#   4818267: 0,
#   4818271: 0,
#   4728622: 2.0,
#   4729578: 2.0,
#   4729579: 0.0,
#   4729581: 0,
#   4729582: 0,
#   4729583: 0,
#   4729584: 0,
#   4777656: 1.0,
#   4729572: 2.0,
#   4734322: 2.0,
#   4734323: 2.0,
#   4734324: 2.0,
#   4734325: 2.0,
#   4734327: 2.0,
#   4734328: 2.0,
#   4734329: 2.0,
#   4734524: 2.0,
#   4729573: 1.0,
#   4735059: 0.0,
#   4735060: 2.0,
#   4735061: 2.0,
#   4735062: 2.0,
#   4735063: 0.0,
#   4742898: 0,
#   4742924: 0,
#   4744909: 0,
#   4729574: 2.0,
#   4778854: 2.0,
#   4778855: 2.0,
#   4778856: 2.0,
#   4778858: 0,
#   4778859: 0,
#   4778860: 0,
#   4778861: 0,
#   4778868: 0,
#   4781268: 0,
#   4781269: 0,
#   4781290: 1.0,
#   4857822: 0,
#   4729575: 0,
#   4780984: 0,
#   4780985: 0,
#   4780986: 0,
#   4781525: 0,
#   4729576: 0.0,
#   4780987: 0,
#   4780988: 0,
#   4780989: 0,
#   4782798: 2.0,
#   4749492: 0,
#   4853574: 0,
#   4738012: 2.0,
# ...
