# %% [markdown]
# ### Вид хранимых данных
# ``` json
# {
#     "course": {
#         "id": 123,
#         "title":""
#         "section": [111, 112, ...]
#         }
#     ,
#     "sections": {
#         111: {
#             "id": 111,
#             "title": "Two",
#             "position": 2,
#             "course_id": 188376,
#             "lessons": [123456, 123457, ...]
#             },
#         112: {
#             "id": 112,
#             "title": "Two",
#             "position": 2,
#             "course_id": 188371,
#             "lessons": [123966, ....]
#             }
#     },
#     "lessons": {
#         123456: {"title":"", "steps":[]},
#         123457: {"title":"", "steps":[]},
#         123458: {"title":"", "steps":[]},
#         123459: {"title":"", "steps":[]},
#     },
#     "steps": {
#         666: {
#             "id": 666,
#             "lesson_id": 123456,
#             "position": 1,
#             "block_name": "text"
#             }
#     }
# }
#
# ```

# %%
from classesAPI import *
from config import token
from pprint import pprint

st = CourseData(token, course_id=188376)
pprint(st.data)
# Out:
# {'course': {'id': 188376,
#             'sections': [365061,
#                          365062,
#                          365713,
#                          371384,
#                          389712,
#                          371385,
#                          371386,
#                          371387,
#                          371388,
#                          371389,
#                          388364],
#             'title': 'Простой python: том 1, основы'},
#  'lessons': {414777: {'id': 414777,
#                       'steps': [1608757,
#                                 5445063,
#                                 1608834,
#                                 4665160,
#                                 4665159,
#                                 1608843,
#                                 1608836,
#                                 4665157,
#                                 5445081,
#                                 5445080,
#                                 4665169,
# ...
