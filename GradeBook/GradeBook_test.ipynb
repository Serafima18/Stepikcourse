# %%
import pandas as pd
from classesAPI import *
from config import token
from pprint import pprint

# %%
grade_book = GradeBook(token, course_id='188376', class_id='62475')
print(grade_book.get_grades())
df = pd.DataFrame.from_dict(grade_book.get_student_grades(student_id=944335224), orient='index', columns=['Score'])
df
# Out:
# [{'id': 29837854, 'course': 188376, 'user': 944335224, 'results': {'1140054-6': {'step_id': 4818237, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140054-5': {'step_id': 4818238, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140054-4': {'step_id': 4818239, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140054-8': {'step_id': 4818266, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140054-7': {'step_id': 4818267, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140054-9': {'step_id': 4818271, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140056-1': {'step_id': 4728622, 'is_passed': True, 'first_success': None, 'total_submissions': 0, 'score': 2.0}, '1140056-3': {'step_id': 4729578, 'is_passed': True, 'first_success': 1, 'total_submissions': 1, 'score': 2.0}, '1140056-4': {'step_id': 4729579, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0.0}, '1140056-5': {'step_id': 4729581, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140056-6': {'step_id': 4729582, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140056-7': {'step_id': 4729583, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140056-8': {'step_id': 4729584, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140056-2': {'step_id': 4777656, 'is_passed': True, 'first_success': 2, 'total_submissions': 2, 'score': 1.0}, '1140280-1': {'step_id': 4729572, 'is_passed': True, 'first_success': None, 'total_submissions': 0, 'score': 2.0}, '1140280-2': {'step_id': 4734322, 'is_passed': True, 'first_success': 1, 'total_submissions': 1, 'score': 2.0}, '1140280-3': {'step_id': 4734323, 'is_passed': True, 'first_success': 1, 'total_submissions': 1, 'score': 2.0}, '1140280-4': {'step_id': 4734324, 'is_passed': True, 'first_success': 3, 'total_submissions': 3, 'score': 2.0}, '1140280-5': {'step_id': 4734325, 'is_passed': True, 'first_success': None, 'total_submissions': 0, 'score': 2.0}, '1140280-6': {'step_id': 4734327, 'is_passed': True, 'first_success': 6, 'total_submissions': 6, 'score': 2.0}, '1140280-7': {'step_id': 4734328, 'is_passed': True, 'first_success': None, 'total_submissions': 0, 'score': 2.0}, '1140280-8': {'step_id': 4734329, 'is_passed': True, 'first_success': 4, 'total_submissions': 4, 'score': 2.0}, '1140280-9': {'step_id': 4734524, 'is_passed': True, 'first_success': 3, 'total_submissions': 3, 'score': 2.0}, '1140281-1': {'step_id': 4729573, 'is_passed': True, 'first_success': 1, 'total_submissions': 1, 'score': 1.0}, '1140281-2': {'step_id': 4735059, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0.0}, '1140281-3': {'step_id': 4735060, 'is_passed': True, 'first_success': None, 'total_submissions': 0, 'score': 2.0}, '1140281-4': {'step_id': 4735061, 'is_passed': True, 'first_success': None, 'total_submissions': 0, 'score': 2.0}, '1140281-5': {'step_id': 4735062, 'is_passed': True, 'first_success': 1, 'total_submissions': 1, 'score': 2.0}, '1140281-6': {'step_id': 4735063, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0.0}, '1140281-7': {'step_id': 4742898, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140281-9': {'step_id': 4742924, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140281-8': {'step_id': 4744909, 'is_passed': False, 'first_success': None, 'total_submissions': 0, 'score': 0}, '1140282-1': {'step_id': 4729574, 'is_passed': True, 'first_success': None, 'total_submissions': 0, 'score': 2.0}, '1140282-3': {'step_id': 4778854, 'is_passed': True, 'first_success': 1, 'total_submissions': 1, 'score': 2.0}, '1140282-4': {'step_id': 4778855, 'is_passed': True, 'first_succes ...
#          Score
# 4818237    0.0
# 4818238    0.0
# 4818239    0.0
# 4818266    0.0
# 4818267    0.0
# ...        ...
# 5450928    0.0
# 5450929    0.0
# 5596847    0.0
# 5596849    0.0
# 5596850    0.0
#
# [355 rows x 1 columns]
